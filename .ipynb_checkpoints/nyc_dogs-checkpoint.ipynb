# %%
#!pip install geopandas
#!pip install matplotlib
# !pip install mapclassify
# Out:
# Collecting mapclassify
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading mapclassify-2.8.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting networkx>=2.7 (from mapclassify)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\sean8\onedrive\desktop\capstone-xseanw\venv\lib\site-packages (from mapclassify) (2.1.3)
# Requirement already satisfied: pandas!=1.5.0,>=1.4 in c:\users\sean8\onedrive\desktop\capstone-xseanw\venv\lib\site-packages (from mapclassify) (2.2.3)
# Collecting scikit-learn>=1.0 (from mapclassify)
#   Downloading scikit_learn-1.5.2-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Collecting scipy>=1.8 (from mapclassify)
#   Downloading scipy-1.14.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.8 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 537.6 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sean8\onedrive\desktop\capstone-xseanw\venv\lib\site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sean8\onedrive\desktop\capstone-xseanw\venv\lib\site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sean8\onedrive\desktop\capstone-xseanw\venv\lib\site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2024.2)
# Collecting joblib>=1.2.0 (from scikit-learn>=1.0->mapclassify)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.0->mapclassify)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in c:\users\sean8\onedrive\desktop\capstone-xseanw\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas!=1.5.0,>=1.4->mapclassify) (1.16.0)
# Downloading mapclassify-2.8.1-py3-none-any.whl (59 kB)
#    ---------------------------------------- 0.0/59.1 kB ? eta -:--:--
#    ---------------------------------------- 59.1/59.1 kB 3.3 MB/s eta 0:00:00
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.7 MB 2.4 MB/s eta 0:00:01
#    --------- ------------------------------ 0.4/1.7 MB 4.5 MB/s eta 0:00:01
#    --------------------- ------------------ 0.9/1.7 MB 7.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.2/1.7 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 7.9 MB/s eta 0:00:00
# Downloading scikit_learn-1.5.2-cp311-cp311-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/11.0 MB 18.6 MB/s eta 0:00:01
#    - -------------------------------------- 0.3/11.0 MB 18.6 MB/s eta 0:00:01
#    - -------------------------------------- 0.3/11.0 MB 18.6 MB/s eta 0:00:01
#    - -------------------------------------- 0.3/11.0 MB 18.6 MB/s eta 0:00:01
#    - -------------------------------------- 0.4/11.0 MB 1.9 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/11.0 MB 3.1 MB/s eta 0:00:04
#    ------ --------------------------------- 1.8/11.0 MB 5.7 MB/s eta 0:00:02
#    -------- ------------------------------- 2.2/11.0 MB 6.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.1/11.0 MB 7.5 MB/s eta 0:00:02
#    --------------- ------------------------ 4.1/11.0 MB 9.1 MB/s eta 0:00:01
#    ------------------ --------------------- 5.1/11.0 MB 10.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.2/11.0 MB 11.3 MB/s eta 0:00:01
#    -------------------------- ------------- 7.2/11.0 MB 12.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.9/11.0 MB 12.3 MB/s eta 0:00:01
#    --------------------------------- ------ 9.3/11.0 MB 13.5 MB/s eta 0:00:01
#    -------------------------------------- - 10.5/11.0 MB 14.2 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 20.5 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 20.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 17.2 MB/s eta 0:00:00
# Downloading scipy-1.14.1-cp311-cp311-win_amd64.whl (44.8 MB)
#    ---------------------------------------- 0.0/44.8 MB ? eta -:--:--
#    - -------------------------------------- 1.4/44.8 MB 29.8 MB/s eta 0:00:02
#    -- ------------------------------------- 2.7/44.8 MB 28.1 MB/s eta 0:00:02
#    --- ------------------------------------ 3.6/44.8 MB 25.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 5.0/44.8 MB 26.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 6.4/44.8 MB 27.1 MB/s eta 0:00:02
#    ------ --------------------------------- 7.5/44.8 MB 26.7 MB/s eta 0:00:02
#    ------- -------------------------------- 8.2/44.8 MB 26.2 MB/s eta 0:00:02
#    --------- ------------------------------ 10.1/44.8 MB 26.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 11.3/44.8 MB 27.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 13.2/44.8 MB 29.8 MB/s eta 0:00:02
#    ------------- -------------------------- 14.8/44.8 MB 31.2 MB/s eta 0:00:01
#    -------------- ------------------------- 16.8/44.8 MB 32.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 18.8/44.8 MB 38.5 MB/s eta 0:00:01
#    ------------------ --------------------- 20.5/44.8 MB 38.5 MB/s eta 0:00:01
#    ------------------- -------------------- 22.3/44.8 MB 38.5 MB/s eta 0:00:01
#    --------------------- ------------------ 23.6/44.8 MB 36.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 25.7/44.8 MB 38.6 MB/s eta 0:00:01
#    ------------------------ --------------- 27.0/44.8 MB 36.4 MB/s eta 0:00:01
#    ------------------------- -------------- 28.7/44.8 MB 36.4 MB/s eta 0:00:01
#    -------------------------- ------------- 29.9/44.8 MB 34.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 32.0/44.8 MB 36.4 MB/s eta 0:00:01
#    ------------------------------ --------- 33.7/44.8 MB 34.4 MB/s eta 0:00:01
#    ------------------------------- -------- 35.8/44.8 MB 38.5 MB/s eta 0:00:01
#    --------------------------------- ------ 37.4/44.8 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 38.8/44.8 MB 38.5 MB/s eta 0:00:01
#    ------------------------------------ --- 40.9/44.8 MB 38.5 MB/s eta 0:00:01
#    -------------------------------------- - 42.6/44.8 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  44.2/44.8 MB 38.6 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------------- 44.8/44.8 MB 17.7 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ---------------------------------------- 0.0/301.8 kB ? eta -:--:--
#    - -------------------------------------- 10.2/301.8 kB ? eta -:--:--
#    - -------------------------------------- 10.2/301.8 kB ? eta -:--:--
#    - -------------------------------------- 10.2/301.8 kB ? eta -:--:--
#    - -------------------------------------- 10.2/301.8 kB ? eta -:--:--
#    ---------------------------------------- 301.8/301.8 kB 1.3 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, networkx, joblib, scikit-learn, mapclassify
# Successfully installed joblib-1.4.2 mapclassify-2.8.1 networkx-3.4.2 scikit-learn-1.5.2 scipy-1.14.1 threadpoolctl-3.5.0

# %%
#import the libraries needed for project
import geopandas
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('dark_background')
import mapclassify

# %%
#read the csv files into the project. Each one has name for the dataframe it features
gdf=geopandas.read_file('nyc_bb.geojson')
dogs = pd.read_csv('dogs_lic.csv')
income = pd.read_csv('borough_income.csv')

# %%
gdf
# Out:
#   boro_code      boro_name     shape_area     shape_leng  \
# 0         3       Brooklyn  1934142775.63  728147.130565
# 1         5  Staten Island  1623618684.31  325910.306061
# 2         1      Manhattan  636646082.483  360037.525777
# 3         2          Bronx  1187174772.32  463180.578878
# 4         4         Queens   3041418003.6  888197.010944
#
#                                             geometry
# 0  MULTIPOLYGON (((-73.86327 40.58388, -73.86381 ...
# 1  MULTIPOLYGON (((-74.05051 40.56642, -74.05047 ...
# 2  MULTIPOLYGON (((-74.01093 40.68449, -74.01193 ...
# 3  MULTIPOLYGON (((-73.89681 40.79581, -73.89694 ...
# 4  MULTIPOLYGON (((-73.82645 40.59053, -73.82642 ...

# %%
gdf.plot('boro_name')
# Out:
# <Axes: >

# %%
dogs[['boro_name', 'BreedName', 'X']].groupby(['boro_name', 'BreedName']).count().reset_index().rename(columns={'X':'Count'})
# Out:
#           boro_name                     BreedName  Count
# 0             Bronx                 Affenpinscher      2
# 1             Bronx                  Afghan Hound      3
# 2             Bronx              Airedale Terrier      1
# 3             Bronx                         Akita     18
# 4             Bronx              Akita Crossbreed      6
# ...             ...                           ...    ...
# 1216  Staten Island                       Whippet      7
# 1217  Staten Island              Wire Fox Terrier     15
# 1218  Staten Island                Xoloitzcuintli      1
# 1219  Staten Island             Yorkshire Terrier    738
# 1220  Staten Island  Yorkshire Terrier Crossbreed     41
#
# [1221 rows x 3 columns]

# %%
dogs_grouped = dogs[['boro_name', 'BreedName', 'X']].groupby(['boro_name', 'BreedName']).size().reset_index(name='count')

# %%
#filter out unknown in breedname
for x in dogs_grouped.index:
    if dogs_grouped.loc[x, 'BreedName'] == 'Unknown':
        dogs_grouped.drop(x, inplace=True)

# %%
top_dog = dogs_grouped.groupby('boro_name').apply(lambda x: x.nlargest(3, 'count')).reset_index(drop=True)

top_dog
# Out:
# C:\Users\sean8\AppData\Local\Temp\ipykernel_27572\738194143.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top_dog = dogs_grouped.groupby('boro_name').apply(lambda x: x.nlargest(3, 'count')).reset_index(drop=True)
#         boro_name           BreedName  count
# 0           Bronx   Yorkshire Terrier   1237
# 1           Bronx            Shih Tzu   1101
# 2           Bronx           Chihuahua    861
# 3        Brooklyn   Yorkshire Terrier   2002
# 4        Brooklyn            Shih Tzu   1893
# 5        Brooklyn           Chihuahua   1511
# 6       Manhattan   Yorkshire Terrier   2087
# 7       Manhattan           Chihuahua   1922
# 8       Manhattan            Shih Tzu   1843
# 9          Queens   Yorkshire Terrier   1704
# 10         Queens            Shih Tzu   1569
# 11         Queens             Maltese   1174
# 12  Staten Island   Yorkshire Terrier    738
# 13  Staten Island            Shih Tzu    731
# 14  Staten Island  Labrador Retriever    580

# %%
boro_dog = gdf.merge(top_dog, on='boro_name', how='inner')

boro_dog
# Out:
#    boro_code      boro_name     shape_area     shape_leng  \
# 0          3       Brooklyn  1934142775.63  728147.130565
# 1          3       Brooklyn  1934142775.63  728147.130565
# 2          3       Brooklyn  1934142775.63  728147.130565
# 3          5  Staten Island  1623618684.31  325910.306061
# 4          5  Staten Island  1623618684.31  325910.306061
# 5          5  Staten Island  1623618684.31  325910.306061
# 6          1      Manhattan  636646082.483  360037.525777
# 7          1      Manhattan  636646082.483  360037.525777
# 8          1      Manhattan  636646082.483  360037.525777
# 9          2          Bronx  1187174772.32  463180.578878
# 10         2          Bronx  1187174772.32  463180.578878
# 11         2          Bronx  1187174772.32  463180.578878
# 12         4         Queens   3041418003.6  888197.010944
# 13         4         Queens   3041418003.6  888197.010944
# 14         4         Queens   3041418003.6  888197.010944
#
#                                              geometry           BreedName  \
# 0   MULTIPOLYGON (((-73.86327 40.58388, -73.86381 ...   Yorkshire Terrier
# 1   MULTIPOLYGON (((-73.86327 40.58388, -73.86381 ...            Shih Tzu
# 2   MULTIPOLYGON (((-73.86327 40.58388, -73.86381 ...           Chihuahua
# 3   MULTIPOLYGON (((-74.05051 40.56642, -74.05047 ...   Yorkshire Terrier
# 4   MULTIPOLYGON (((-74.05051 40.56642, -74.05047 ...            Shih Tzu
# 5   MULTIPOLYGON (((-74.05051 40.56642, -74.05047 ...  Labrador Retriever
# 6   MULTIPOLYGON (((-74.01093 40.68449, -74.01193 ...   Yorkshire Terrier
# 7   MULTIPOLYGON (((-74.01093 40.68449, -74.01193 ...           Chihuahua
# 8   MULTIPOLYGON (((-74.01093 40.68449, -74.01193 ...            Shih Tzu
# 9   MULTIPOLYGON (((-73.89681 40.79581, -73.89694 ...   Yorkshire Terrier
# 10  MULTIPOLYGON (((-73.89681 40.79581, -73.89694 ...            Shih Tzu
# 11  MULTIPOLYGON (((-73.89681 40.79581, -73.89694 ...           Chihuahua
# 12  MULTIPOLYGON (((-73.82645 40.59053, -73.82642 ...   Yorkshire Terrier
# 13  MULTIPOLYGON (((-73.82645 40.59053, -73.82642 ...            Shih Tzu
# 14  MULTIPOLYGON (((-73.82645 40.59053, -73.82642 ...             Maltese
#
#     count
# 0    2002
# 1    1893
# 2    1511
# 3     738
# 4     731
# 5     580
# 6    2087
# 7    1922
# 8    1843
# 9    1237
# 10   1101
# 11    861
# 12   1704
# 13   1569
# 14   1174

# %%
boro_dog.plot('count', legend=True, cmap='OrRd', scheme='natural_breaks')
# Out:
# <Axes: >

# %%
boro_dog
# Out:
#    boro_code      boro_name     shape_area     shape_leng  \
# 0          3       Brooklyn  1934142775.63  728147.130565
# 1          3       Brooklyn  1934142775.63  728147.130565
# 2          3       Brooklyn  1934142775.63  728147.130565
# 3          5  Staten Island  1623618684.31  325910.306061
# 4          5  Staten Island  1623618684.31  325910.306061
# 5          5  Staten Island  1623618684.31  325910.306061
# 6          1      Manhattan  636646082.483  360037.525777
# 7          1      Manhattan  636646082.483  360037.525777
# 8          1      Manhattan  636646082.483  360037.525777
# 9          2          Bronx  1187174772.32  463180.578878
# 10         2          Bronx  1187174772.32  463180.578878
# 11         2          Bronx  1187174772.32  463180.578878
# 12         4         Queens   3041418003.6  888197.010944
# 13         4         Queens   3041418003.6  888197.010944
# 14         4         Queens   3041418003.6  888197.010944
#
#                                              geometry           BreedName  \
# 0   MULTIPOLYGON (((-73.86327 40.58388, -73.86381 ...   Yorkshire Terrier
# 1   MULTIPOLYGON (((-73.86327 40.58388, -73.86381 ...            Shih Tzu
# 2   MULTIPOLYGON (((-73.86327 40.58388, -73.86381 ...           Chihuahua
# 3   MULTIPOLYGON (((-74.05051 40.56642, -74.05047 ...   Yorkshire Terrier
# 4   MULTIPOLYGON (((-74.05051 40.56642, -74.05047 ...            Shih Tzu
# 5   MULTIPOLYGON (((-74.05051 40.56642, -74.05047 ...  Labrador Retriever
# 6   MULTIPOLYGON (((-74.01093 40.68449, -74.01193 ...   Yorkshire Terrier
# 7   MULTIPOLYGON (((-74.01093 40.68449, -74.01193 ...           Chihuahua
# 8   MULTIPOLYGON (((-74.01093 40.68449, -74.01193 ...            Shih Tzu
# 9   MULTIPOLYGON (((-73.89681 40.79581, -73.89694 ...   Yorkshire Terrier
# 10  MULTIPOLYGON (((-73.89681 40.79581, -73.89694 ...            Shih Tzu
# 11  MULTIPOLYGON (((-73.89681 40.79581, -73.89694 ...           Chihuahua
# 12  MULTIPOLYGON (((-73.82645 40.59053, -73.82642 ...   Yorkshire Terrier
# 13  MULTIPOLYGON (((-73.82645 40.59053, -73.82642 ...            Shih Tzu
# 14  MULTIPOLYGON (((-73.82645 40.59053, -73.82642 ...             Maltese
#
#     count
# 0    2002
# 1    1893
# 2    1511
# 3     738
# 4     731
# 5     580
# 6    2087
# 7    1922
# 8    1843
# 9    1237
# 10   1101
# 11    861
# 12   1704
# 13   1569
# 14   1174
